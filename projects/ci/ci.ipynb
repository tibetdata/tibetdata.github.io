# %%
import pandas as pd
import json
from pprint import pprint

with open('data.json') as data_file:    
    data = json.load(data_file)
    #df = pd.read_json(data)

#print(df)

#pprint(data)

# %%
df = pd.read_csv('data1.csv')
print(df)
# Out:
#             countries                                  universities.href  \
# 0         Afghanistan  http://english.hanban.org/confuciousinstitutes...
# 1             Albania  http://english.hanban.org/article/2014-01/03/c...
# 2           Argentina  http://www.unlp.edu.ar/articulo/2011/2/22/inst...
# 3             Armenia                                                NaN
# 4           Australia                                                NaN
# 5             Austria                                                NaN
# 6          Azerbaijan                                                NaN
# 7                 NaN                                                NaN
# 8                 NaN               http://www.institutoconfucio.edu.ar/
# 9             Bahamas  http://www.brusov.am/en/structure/centers/conf...
# 10            Bahrain       http://www.bangor.ac.uk/confucius-institute/
# 11         Bangladesh                                                NaN
# 12            Belarus                                                NaN
# 13            Belgium                                                NaN
# 14              Benin                                                NaN
# 15            Bolivia                                                NaN
# 16           Botswana                                                NaN
# 17             Brazil                                                NaN
# 18           Bulgaria          http://www.cdu.edu.au/confucius-institute
# 19            Burundi                                                NaN
# 20           Cambodia                                                NaN
# 21           Cameroon                                                NaN
# 22             Canada                                                NaN
# 23              Chile                                                NaN
# 24           Colombia                                                NaN
# 25              Congo                                                NaN
# 26         Costa Rica  http://confuciusinstitute.unl.edu/Confucius%20...
# 27            Croatia                                                NaN
# 28               Cuba                                                NaN
# 29     Czech Republic                                                NaN
# ...               ...                                                ...
# 25562             NaN                                                NaN
# 25563             NaN                                                NaN
# 25564             NaN                                                NaN
# 25565             NaN                                                NaN
# 25566             NaN                                                NaN
# 25567             NaN                                                NaN
# 25568             NaN                                                NaN
# 25569             NaN                                                NaN
# 25570             NaN                                                NaN
# 25571             NaN                                                NaN
# 25572             NaN                                                NaN
# 25573             NaN                                                NaN
# 25574             NaN                                                NaN
# 25575             NaN                                                NaN
# 25576             NaN                                                NaN
# 25577             NaN                                                NaN
# 25578             NaN                                                NaN
# 25579             NaN                                                NaN
# 25580             NaN                                                NaN
# 25581             NaN                                                NaN
# 25582             NaN                                                NaN
# 25583             NaN                                                NaN
# 25584             NaN                                                NaN
# 25585             NaN                                                NaN
# 25586             NaN                                                NaN
# 25587             NaN                                                NaN
# 25588             NaN                                                NaN
# 25589             NaN           http://english.hanban.org/node_42189.htm
# 25590             NaN           http://www.unza.zm/institutes/confucius/
# 25591             NaN           http://english.hanban.org/node_10900.htm
#
#                                        universities.text
# 0                                       Kabul University
# 1                                   University of Tirana
# 2                        National University of La Plata
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                             University of Buenos Aires
# 9      Yerevan State Linguistic University After V.Br...
# 10                                     Bangor University
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                             Charles Darwin University
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                       Confucius Institute in Adelaide
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 25562                                                NaN
# 25563                                                NaN
# 25564                                                NaN
# 25565                                                NaN
# 25566                                                NaN
# 25567                                                NaN
# 25568                                                NaN
# 25569                                                NaN
# 25570                                                NaN
# 25571                                                NaN
# 25572                                                NaN
# 25573                                                NaN
# 25574                                                NaN
# 25575                                                NaN
# 25576                                                NaN
# 25577                                                NaN
# 25578                                                NaN
# 25579                                                NaN
# 25580                                                NaN
# 25581                                                NaN
# 25582                                                NaN
# 25583                                                NaN
# 25584                                                NaN
# 25585                                                NaN
# 25586                                                NaN
# 25587                                                NaN
# 25588                                                NaN
# 25589     Samarkand State Institute of Foreign Languages
# 25590                               University of Zambia
# 25591                             University of Zimbabwe
#
# [25592 rows x 3 columns]
